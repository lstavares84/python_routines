# %%
# !pip install pyvis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyvis in /home/lstavares/.local/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/lib/python3/dist-packages (from pyvis) (8.14.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/lib/python3/dist-packages (from pyvis) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /home/lstavares/.local/lib/python3.11/site-packages (from pyvis) (3.0.2)
# Requirement already satisfied: networkx>=1.11 in /usr/lib/python3/dist-packages (from pyvis) (2.8.8)
# Requirement already satisfied: backcall in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (2.15.1)
# Requirement already satisfied: stack-data in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (5.5.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/lib/python3/dist-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in /usr/lib/python3/dist-packages (from stack-data->ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: pure-eval in /usr/lib/python3/dist-packages (from stack-data->ipython>=5.3.0->pyvis) (0.0.0)

# %%
#Tabela de distância entre as capitais
distancias = {
'SE':{'SE': 0,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': 294,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': 356,'MA': None,'SP': None,'PI': None,'ES': None},
'PA':{'SE': None,'PA': 0,'MG': None,'RR': 6083,'DF': 716,'MS': None,'MT': 2941,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': 5298,'RN': None,'TO': 1283,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': 806,'SP': None,'PI': None,'ES': None},
'MG':{'SE': None,'PA': None,'MG': 0,'RR': None,'DF': None,'MS': 1453,'MT': None,'PR': None,'SC': None,'CE': None,'GO': 906,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': 434,'BA': 1372,'MA': None,'SP': 586,'PI': None,'ES': 524},
'RR':{'SE': None,'PA': None,'MG': None,'RR': 0,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': 785,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'DF':{'SE': None,'PA': None,'MG': 716,'RR': None,'DF': 0,'MS': 1134,'MT': 1133,'PR': None,'SC': None,'CE': None,'GO': 209,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': 973,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': 1446,'MA': None,'SP': None,'PI': None,'ES': None},
'MS':{'SE': None,'PA': None,'MG': 1453,'RR': None,'DF': 1134,'MS': 0,'MT': 694,'PR': 991,'SC': None,'CE': None,'GO': 935,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': 1014,'PI': None,'ES': None},
'MT':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': 1133,'MS': 694,'MT': 0,'PR': None,'SC': None,'CE': None,'GO': 934,'PB': None,'AP': None,'AL': None,'AM': 2357,'RN': None,'TO': 1784,'RS': None,'RO': 1456,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'PR':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': 991,'MT': None,'PR': 0,'SC': 300,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': 408,'PI': None,'ES': None},
'SC':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': 300,'SC': 0,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': 476,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'CE':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': 0,'GO': None,'PB': 688,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': 800,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': 634,'ES': None},
'GO':{'SE': None,'PA': None,'MG': 906,'RR': None,'DF': 209,'MS': 935,'MT': 934,'PR': None,'SC': None,'CE': None,'GO': 0,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': 874,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': 1643,'MA': None,'SP': None,'PI': None,'ES': None},
'PB':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': 688,'GO': None,'PB': 0,'AP': None,'AL': None,'AM': None,'RN': 185,'TO': None,'RS': None,'RO': None,'PE': 120,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'AP':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': 0,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'AL':{'SE': 294,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': 0,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': 285,'AC': None,'RJ': None,'BA': 632,'MA': None,'SP': None,'PI': None,'ES': None},
'AM':{'SE': None,'PA': 5298,'MG': None,'RR': 785,'DF': None,'MS': None,'MT': 2357,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': 0,'RN': None,'TO': None,'RS': None,'RO': 901,'PE': None,'AC': 1445,'RJ': None,'BA': None,'MA': 5335,'SP': None,'PI': None,'ES': None},
'RN':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': 537,'GO': None,'PB': 185,'AP': None,'AL': None,'AM': None,'RN': 0,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'TO':{'SE': None,'PA': 1283,'MG': None,'RR': None,'DF': 973,'MS': None,'MT': 1784,'PR': None,'SC': None,'CE': None,'GO': 874,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': 0,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': 1454,'MA': 1386,'SP': None,'PI': 1401,'ES': None},
'RS':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': 476,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': 0,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'RO':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': 1456,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': 901,'RN': None,'TO': None,'RS': None,'RO': 0,'PE': None,'AC': 544,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'PE':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': 800,'GO': None,'PB': 120,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': 0,'AC': None,'RJ': None,'BA': 839,'MA': None,'SP': None,'PI': None,'ES': None},
'AC':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': 544,'PE': None,'AC': 0,'RJ': None,'BA': None,'MA': None,'SP': None,'PI': None,'ES': None},
'RJ':{'SE': None,'PA': None,'MG': 434,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': 0,'BA': None,'MA': None,'SP': 429,'PI': None,'ES': 521},
'BA':{'SE': 356,'PA': None,'MG': 1372,'RR': None,'DF': 1446,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': 1643,'PB': None,'AP': None,'AL': 632,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': 839,'AC': None,'RJ': None,'BA': 0,'MA': None,'SP': None,'PI': 1163,'ES': 1202},
'MA':{'SE': None,'PA': 806,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': 1386,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': None,'MA': 0,'SP': None,'PI': 446,'ES': None},
'SP':{'SE': None,'PA': None,'MG': 586,'RR': None,'DF': None,'MS': 1014,'MT': None,'PR': 408,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': 429,'BA': None,'MA': None,'SP': 0,'PI': None,'ES': None},
'PI':{'SE': None,'PA': None,'MG': None,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': 634,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': None,'BA': 1163,'MA': 446,'SP': None,'PI': 0,'ES': None},
'ES':{'SE': None,'PA': None,'MG': 524,'RR': None,'DF': None,'MS': None,'MT': None,'PR': None,'SC': None,'CE': None,'GO': None,'PB': None,'AP': None,'AL': None,'AM': None,'RN': None,'TO': None,'RS': None,'RO': None,'PE': None,'AC': None,'RJ': 521,'BA': 1202,'MA': None,'SP': None,'PI': None,'ES': 0}

}

# %%
# Tabela de preços do óleo diesel por estado
tabela_preco_diesel = {
    "AC": 6.52,
    "AL": 4.75,
    "AM": 5.16,
    "AP": 5.06,
    "BA": 5.12,
    "CE": 5.04,
    "DF": 4.79,
    "ES": 4.89,
    "GO": 4.80,
    "MA": 4.74,
    "MG": 4.79,
    "MS": 5.04,
    "MT": 5.12,
    "PA": 5.37,
    "PB": 4.75,
    "PE": 5.13,
    "PI": 4.87,
    "PR": 4.82,
    "RJ": 5.06,
    "RN": 5.02,
    "RO": 5.35,
    "RR": 5.37,
    "RS": 4.93,
    "SC": 4.96,
    "SP": 4.91,
    "SE": 4.93,
    "TO": 4.95,
}

# %%
# Lista de todas as capitais
capitais = [
    'SE', 'PA', 'MG', 'RR', 'DF', 'MS', 'MT', 'PR', 'SC', 'CE', 'GO', 'PB',
    'AP', 'AL', 'AM', 'RN', 'TO', 'RS', 'RO', 'PE', 'AC', 'RJ', 'BA', 'MA',
    'SP', 'PI', 'ES'
]

# %%
from pyvis.network import Network
from IPython.display import display, HTML
import pandas as pd

# Defina os dados do grafo com base nas distâncias entre as cidades
city_graph = Network(height="750px", width="100%", bgcolor="#222222", font_color="white")
city_graph.barnes_hut()

# Adicione nós e arestas ao grafo com base nas distâncias
for city1 in distancias:
    city_graph.add_node(city1, label=city1)
    for city2 in distancias[city1]:
        if distancias[city1][city2] is not None:
            distance = distancias[city1][city2]
            city_graph.add_node(city2, label=city2)
            city_graph.add_edge(city1, city2, value=distance)

# Salve o gráfico em um arquivo HTML
city_graph.save_graph("city_distances.html")
city_graph.show("city_distances.html")
# Out:
# city_distances.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 20
#      18 # Salve o gráfico em um arquivo HTML
#      19 city_graph.save_graph("city_distances.html")
# ---> 20 city_graph.show("city_distances.html")
#
# File ~/.local/lib/python3.11/site-packages/pyvis/network.py:546, in Network.show(self, name, local, notebook)
#     544 print(name)
#     545 if notebook:
# --> 546     self.write_html(name, open_browser=False,notebook=True)
#     547 else:
#     548     self.write_html(name, open_browser=True)
#
# File ~/.local/lib/python3.11/site-packages/pyvis/network.py:515, in Network.write_html(self, name, local, notebook, open_browser)
#     513 getcwd_name = name
#     514 check_html(getcwd_name)
# --> 515 self.html = self.generate_html(notebook=notebook)
#     517 if self.cdn_resources == "local":
#     518     if not os.path.exists("lib"):
#
# File ~/.local/lib/python3.11/site-packages/pyvis/network.py:479, in Network.generate_html(self, name, local, notebook)
#     476 else:
#     477     physics_enabled = self.options.physics.enabled
# --> 479 self.html = template.render(height=height,
#     480                             width=width,
#     481                             nodes=nodes,
#     482                             edges=edges,
#     483                             heading=heading,
#     484                             options=options,
#     485                             physics_enabled=physics_enabled,
#     486                             use_DOT=self.use_DOT,
#     487                             dot_lang=self.dot_lang,
#     488                             widget=self.widget,
#     489                             bgcolor=self.bgcolor,
#     490                             conf=self.conf,
#     491                             tooltip_link=use_link_template,
#     492                             neighborhood_highlight=self.neighborhood_highlight,
#     493                             select_menu=self.select_menu,
#     494                             filter_menu=self.filter_menu,
#     495                             notebook=notebook,
#     496                             cdn_resources=self.cdn_resources
#     497                             )
#     498 return self.html
#
# AttributeError: 'NoneType' object has no attribute 'render'

# %%
def dijkstra(start, end, distancias, tabela_preco_diesel):
    # Verifique se o nó de início e o nó de destino estão presentes na tabela de distâncias
    if start not in distancias or end not in distancias:
        print("Nó de início ou destino não encontrado na tabela de distâncias.")
        return None, None

    # Variáveis para armazenar a distância total (f) e a distância acumulada (g) entre as cidades definidas como INÍCIO e FIM
    g = {node: float('inf') for node in distancias}
    f = {node: float('inf') for node in distancias}

    parents = {node: None for node in distancias}  # nó superior ou nó anterior

    # PREDEFINIÇÃO de variáveis antes de começar a calcular
    g[start] = 0  # Distância total (f) e distância acumulada (g) a partir do ponto de INÍCIO
    f[start] = 0  # Distância total (f) e distância acumulada (g) a partir do ponto de INÍCIO
    closed = set()  # Variável para armazenar os caminhos possíveis já testados
    open_set = {start}  # Variável para armazenar os caminhos possíveis A SEREM testados

    # Variáveis para armazenar os caminhos com a menor distância e menor custo
    menor_distancia_caminho = None
    menor_custo_caminho = None

    # Variáveis para armazenar a menor distância total e menor custo total
    menor_distancia_total = float('inf')
    menor_custo_total = float('inf')

    ### LOOP PARA CALCULAR A MENOR DISTÂNCIA
    while open_set:  # Enquanto houver caminhos não testados...
        # Verifica o caminho atual com a menor distância entre a cidade atual e a cidade vizinha e continue procurando
        current = min(open_set, key=lambda node: f[node])

        # Verifica se o nó atual não é None
        if current is None:
            break

        # SE a cidade atual (nó) for o destino (FIM), calcule do fim até o início o caminho completo usando os nós pais
        if current == end:
            path = []
            while current:
                path.append(current)
                current = parents[current]
            path.reverse()

            # Calcula a distância total percorrida
            total_distance = g[end]

            # Calcula o custo total percorrido
            total_cost = 0

            # Calcula e imprime as distâncias entre os nós ao longo do caminho, considerando os valores da tabela de preços do diesel
            diesel_costs = []
            for i in range(len(path) - 1):
                node1 = path[i]
                node2 = path[i + 1]
                distance = distancias[node1][node2]
                diesel_cost = distance * tabela_preco_diesel[node1]
                total_cost += diesel_cost  # Adiciona o custo ao custo total
                diesel_costs.append((f'Distância de {node1} para {node2}: {distance}', f'Custo de diesel: {diesel_cost}'))

            # Verifica se este caminho tem a menor distância total
            if total_distance < menor_distancia_total:
                menor_distancia_total = total_distance
                menor_distancia_caminho = path.copy()

            # Verifica se este caminho tem o menor custo total
            if total_cost < menor_custo_total:
                menor_custo_total = total_cost
                menor_custo_caminho = path.copy()

            # Imprime a solução na tela para o usuário
            # print('\n\n############## CÁLCULO ##############')
            # print(f'O caminho mais curto de {start} para {end} é:')
            # print(f'Caminho: {path}')
            # print(f'Distância total percorrida: {total_distance}')
            # print(f'Custo total percorrido: {total_cost}\n')
            # print('Distâncias e custos de diesel entre os nós ao longo do caminho:')
            # for distance, cost in diesel_costs:
            #     print(distance)
            #     print(cost)

            break  # Saia do loop assim que encontrar o destino

        # FIM DE # SE a cidade atual (nó) for o destino (FIM), calcule do fim até o início o caminho completo usando os nós pais

        # Para mover o nó testado de open_set (não testado) para closed (caminhos testados)
        open_set.remove(current)
        closed.add(current)

        # Identificar todas as cidades vizinhas da cidade/nó atual
        for neighbor in distancias[current]:
            if distancias[current][neighbor] is None:
                continue  # Ignora valores None

            tentative_g = g[current] + distancias[current][neighbor]  # Calcular a distância acumulada do nó/cidade atual para o nó/cidade vizinho selecionado

            # SE a distância acumulada até o nó/cidade selecionado for menor (mas não igual) à distância acumulada atual, por favor, atualize "g[vizinho]"
            # e "f[vizinho]".
            if tentative_g < g[neighbor]:
                parents[neighbor] = current  # Define o nó/cidade atual como pai do vizinho atual
                g[neighbor] = tentative_g  # atualiza a distância acumulada
                f[neighbor] = g[neighbor]  # estima a distância total restante para chegar à cidade/nó final

                # Teste se o vizinho atual não foi testado antes. Mova o vizinho atual testado de não testado
                if neighbor not in open_set:
                    open_set.add(neighbor)
                # FIM DE Teste se o vizinho atual não foi testado antes. Mova o vizinho atual testado de não testado

    # Imprime o caminho com a menor distância total e o menor custo total
    print('\n\n############## SOLUÇÃO ##############')
    print(f'O caminho mais curto de {start} para {end} com a menor distância é:')
    print(f'Caminho: {menor_distancia_caminho}')
    print(f'Distância total percorrida: {menor_distancia_total}\n')

    print(f'O caminho mais curto de {start} para {end} com o menor custo é:')
    print(f'Caminho: {menor_custo_caminho}')
    print(f'Custo total percorrido: {menor_custo_total}\n')

    return menor_distancia_caminho, menor_custo_caminho

# Para cada combinação de start e end
for start in capitais:
    for end in capitais:
        if start != end:  # Evitar combinações iguais de start e end
            print(f"Calculando caminho de {start} para {end}...\n")
            shortest_distance_path, shortest_cost_path = dijkstra(start, end, distancias, tabela_preco_diesel)
            print("-----------------------------------------------------------\n")
            
            # Verifique se os caminhos são diferentes
            if shortest_distance_path != shortest_cost_path:
                print(f"Os caminhos de {start} para {end} têm resultados diferentes!")
                break
# Out:
# Calculando caminho de SE para PA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para PA com a menor distância é:
# Caminho: ['SE', 'BA', 'PI', 'MA', 'PA']
# Distância total percorrida: 2771
#
# O caminho mais curto de SE para PA com o menor custo é:
# Caminho: ['SE', 'BA', 'PI', 'MA', 'PA']
# Custo total percorrido: 13702.1
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para MG...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para MG com a menor distância é:
# Caminho: ['SE', 'BA', 'MG']
# Distância total percorrida: 1728
#
# O caminho mais curto de SE para MG com o menor custo é:
# Caminho: ['SE', 'BA', 'MG']
# Custo total percorrido: 8779.720000000001
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para RR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para RR com a menor distância é:
# Caminho: ['SE', 'BA', 'GO', 'MT', 'AM', 'RR']
# Distância total percorrida: 6075
#
# O caminho mais curto de SE para RR com o menor custo é:
# Caminho: ['SE', 'BA', 'GO', 'MT', 'AM', 'RR']
# Custo total percorrido: 30768.879999999997
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para DF...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para DF com a menor distância é:
# Caminho: ['SE', 'BA', 'DF']
# Distância total percorrida: 1802
#
# O caminho mais curto de SE para DF com o menor custo é:
# Caminho: ['SE', 'BA', 'DF']
# Custo total percorrido: 9158.6
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para MS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para MS com a menor distância é:
# Caminho: ['SE', 'BA', 'GO', 'MS']
# Distância total percorrida: 2934
#
# O caminho mais curto de SE para MS com o menor custo é:
# Caminho: ['SE', 'BA', 'GO', 'MS']
# Custo total percorrido: 14655.24
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para MT...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para MT com a menor distância é:
# Caminho: ['SE', 'BA', 'GO', 'MT']
# Distância total percorrida: 2933
#
# O caminho mais curto de SE para MT com o menor custo é:
# Caminho: ['SE', 'BA', 'GO', 'MT']
# Custo total percorrido: 14650.439999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para PR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para PR com a menor distância é:
# Caminho: ['SE', 'BA', 'MG', 'SP', 'PR']
# Distância total percorrida: 2722
#
# O caminho mais curto de SE para PR com o menor custo é:
# Caminho: ['SE', 'BA', 'MG', 'SP', 'PR']
# Custo total percorrido: 13589.940000000002
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para SC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para SC com a menor distância é:
# Caminho: ['SE', 'BA', 'MG', 'SP', 'PR', 'SC']
# Distância total percorrida: 3022
#
# O caminho mais curto de SE para SC com o menor custo é:
# Caminho: ['SE', 'BA', 'MG', 'SP', 'PR', 'SC']
# Custo total percorrido: 15035.940000000002
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para CE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para CE com a menor distância é:
# Caminho: ['SE', 'AL', 'PE', 'CE']
# Distância total percorrida: 1379
#
# O caminho mais curto de SE para CE com o menor custo é:
# Caminho: ['SE', 'AL', 'PE', 'CE']
# Custo total percorrido: 6907.17
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para GO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para GO com a menor distância é:
# Caminho: ['SE', 'BA', 'GO']
# Distância total percorrida: 1999
#
# O caminho mais curto de SE para GO com o menor custo é:
# Caminho: ['SE', 'BA', 'GO']
# Custo total percorrido: 10167.24
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para PB...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para PB com a menor distância é:
# Caminho: ['SE', 'AL', 'PE', 'PB']
# Distância total percorrida: 699
#
# O caminho mais curto de SE para PB com o menor custo é:
# Caminho: ['SE', 'AL', 'PE', 'PB']
# Custo total percorrido: 3418.77
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para AP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para AP com a menor distância é:
# Caminho: None
# Distância total percorrida: inf
#
# O caminho mais curto de SE para AP com o menor custo é:
# Caminho: None
# Custo total percorrido: inf
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para AL...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para AL com a menor distância é:
# Caminho: ['SE', 'AL']
# Distância total percorrida: 294
#
# O caminho mais curto de SE para AL com o menor custo é:
# Caminho: ['SE', 'AL']
# Custo total percorrido: 1449.4199999999998
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para AM...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para AM com a menor distância é:
# Caminho: ['SE', 'BA', 'GO', 'MT', 'AM']
# Distância total percorrida: 5290
#
# O caminho mais curto de SE para AM com o menor custo é:
# Caminho: ['SE', 'BA', 'GO', 'MT', 'AM']
# Custo total percorrido: 26718.28
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para RN...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para RN com a menor distância é:
# Caminho: ['SE', 'AL', 'PE', 'PB', 'RN']
# Distância total percorrida: 884
#
# O caminho mais curto de SE para RN com o menor custo é:
# Caminho: ['SE', 'AL', 'PE', 'PB', 'RN']
# Custo total percorrido: 4297.52
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para TO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para TO com a menor distância é:
# Caminho: ['SE', 'BA', 'DF', 'TO']
# Distância total percorrida: 2775
#
# O caminho mais curto de SE para TO com o menor custo é:
# Caminho: ['SE', 'BA', 'DF', 'TO']
# Custo total percorrido: 13819.27
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para RS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para RS com a menor distância é:
# Caminho: ['SE', 'BA', 'MG', 'SP', 'PR', 'SC', 'RS']
# Distância total percorrida: 3498
#
# O caminho mais curto de SE para RS com o menor custo é:
# Caminho: ['SE', 'BA', 'MG', 'SP', 'PR', 'SC', 'RS']
# Custo total percorrido: 17396.9
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para RO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para RO com a menor distância é:
# Caminho: ['SE', 'BA', 'GO', 'MT', 'RO']
# Distância total percorrida: 4389
#
# O caminho mais curto de SE para RO com o menor custo é:
# Caminho: ['SE', 'BA', 'GO', 'MT', 'RO']
# Custo total percorrido: 22105.16
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para PE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para PE com a menor distância é:
# Caminho: ['SE', 'AL', 'PE']
# Distância total percorrida: 579
#
# O caminho mais curto de SE para PE com o menor custo é:
# Caminho: ['SE', 'AL', 'PE']
# Custo total percorrido: 2803.17
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para AC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para AC com a menor distância é:
# Caminho: ['SE', 'BA', 'GO', 'MT', 'RO', 'AC']
# Distância total percorrida: 4933
#
# O caminho mais curto de SE para AC com o menor custo é:
# Caminho: ['SE', 'BA', 'GO', 'MT', 'RO', 'AC']
# Custo total percorrido: 25015.559999999998
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para RJ...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para RJ com a menor distância é:
# Caminho: ['SE', 'BA', 'ES', 'RJ']
# Distância total percorrida: 2079
#
# O caminho mais curto de SE para RJ com o menor custo é:
# Caminho: ['SE', 'BA', 'ES', 'RJ']
# Custo total percorrido: 10457.01
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para BA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para BA com a menor distância é:
# Caminho: ['SE', 'BA']
# Distância total percorrida: 356
#
# O caminho mais curto de SE para BA com o menor custo é:
# Caminho: ['SE', 'BA']
# Custo total percorrido: 1755.08
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para MA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para MA com a menor distância é:
# Caminho: ['SE', 'BA', 'PI', 'MA']
# Distância total percorrida: 1965
#
# O caminho mais curto de SE para MA com o menor custo é:
# Caminho: ['SE', 'BA', 'PI', 'MA']
# Custo total percorrido: 9881.66
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para SP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para SP com a menor distância é:
# Caminho: ['SE', 'BA', 'MG', 'SP']
# Distância total percorrida: 2314
#
# O caminho mais curto de SE para SP com o menor custo é:
# Caminho: ['SE', 'BA', 'MG', 'SP']
# Custo total percorrido: 11586.660000000002
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para PI...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para PI com a menor distância é:
# Caminho: ['SE', 'BA', 'PI']
# Distância total percorrida: 1519
#
# O caminho mais curto de SE para PI com o menor custo é:
# Caminho: ['SE', 'BA', 'PI']
# Custo total percorrido: 7709.64
#
# -----------------------------------------------------------
#
# Calculando caminho de SE para ES...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de SE para ES com a menor distância é:
# Caminho: ['SE', 'BA', 'ES']
# Distância total percorrida: 1558
#
# O caminho mais curto de SE para ES com o menor custo é:
# Caminho: ['SE', 'BA', 'ES']
# Custo total percorrido: 7909.32
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para SE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para SE com a menor distância é:
# Caminho: ['PA', 'DF', 'BA', 'SE']
# Distância total percorrida: 2518
#
# O caminho mais curto de PA para SE com o menor custo é:
# Caminho: ['PA', 'DF', 'BA', 'SE']
# Custo total percorrido: 12593.98
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para MG...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para MG com a menor distância é:
# Caminho: ['PA', 'DF', 'MG']
# Distância total percorrida: 1432
#
# O caminho mais curto de PA para MG com o menor custo é:
# Caminho: ['PA', 'DF', 'MG']
# Custo total percorrido: 7274.5599999999995
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para RR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para RR com a menor distância é:
# Caminho: ['PA', 'DF', 'MT', 'AM', 'RR']
# Distância total percorrida: 4991
#
# O caminho mais curto de PA para RR com o menor custo é:
# Caminho: ['PA', 'DF', 'MT', 'AM', 'RR']
# Custo total percorrido: 25390.43
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para DF...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para DF com a menor distância é:
# Caminho: ['PA', 'DF']
# Distância total percorrida: 716
#
# O caminho mais curto de PA para DF com o menor custo é:
# Caminho: ['PA', 'DF']
# Custo total percorrido: 3844.92
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para MS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para MS com a menor distância é:
# Caminho: ['PA', 'DF', 'MS']
# Distância total percorrida: 1850
#
# O caminho mais curto de PA para MS com o menor custo é:
# Caminho: ['PA', 'DF', 'MS']
# Custo total percorrido: 9276.779999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para MT...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para MT com a menor distância é:
# Caminho: ['PA', 'DF', 'MT']
# Distância total percorrida: 1849
#
# O caminho mais curto de PA para MT com o menor custo é:
# Caminho: ['PA', 'DF', 'MT']
# Custo total percorrido: 9271.99
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para PR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para PR com a menor distância é:
# Caminho: ['PA', 'DF', 'MG', 'SP', 'PR']
# Distância total percorrida: 2426
#
# O caminho mais curto de PA para PR com o menor custo é:
# Caminho: ['PA', 'DF', 'MG', 'SP', 'PR']
# Custo total percorrido: 12084.78
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para SC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para SC com a menor distância é:
# Caminho: ['PA', 'DF', 'MG', 'SP', 'PR', 'SC']
# Distância total percorrida: 2726
#
# O caminho mais curto de PA para SC com o menor custo é:
# Caminho: ['PA', 'DF', 'MG', 'SP', 'PR', 'SC']
# Custo total percorrido: 13530.78
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para CE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para CE com a menor distância é:
# Caminho: ['PA', 'MA', 'PI', 'CE']
# Distância total percorrida: 1886
#
# O caminho mais curto de PA para CE com o menor custo é:
# Caminho: ['PA', 'MA', 'PI', 'CE']
# Custo total percorrido: 9529.84
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para GO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para GO com a menor distância é:
# Caminho: ['PA', 'DF', 'GO']
# Distância total percorrida: 925
#
# O caminho mais curto de PA para GO com o menor custo é:
# Caminho: ['PA', 'DF', 'GO']
# Custo total percorrido: 4846.03
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para PB...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para PB com a menor distância é:
# Caminho: ['PA', 'MA', 'PI', 'CE', 'PB']
# Distância total percorrida: 2574
#
# O caminho mais curto de PA para PB com o menor custo é:
# Caminho: ['PA', 'MA', 'PI', 'CE', 'PB']
# Custo total percorrido: 12997.36
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para AP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para AP com a menor distância é:
# Caminho: None
# Distância total percorrida: inf
#
# O caminho mais curto de PA para AP com o menor custo é:
# Caminho: None
# Custo total percorrido: inf
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para AL...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para AL com a menor distância é:
# Caminho: ['PA', 'DF', 'BA', 'AL']
# Distância total percorrida: 2794
#
# O caminho mais curto de PA para AL com o menor custo é:
# Caminho: ['PA', 'DF', 'BA', 'AL']
# Custo total percorrido: 14007.1
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para AM...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para AM com a menor distância é:
# Caminho: ['PA', 'DF', 'MT', 'AM']
# Distância total percorrida: 4206
#
# O caminho mais curto de PA para AM com o menor custo é:
# Caminho: ['PA', 'DF', 'MT', 'AM']
# Custo total percorrido: 21339.83
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para RN...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para RN com a menor distância é:
# Caminho: ['PA', 'MA', 'PI', 'CE', 'PB', 'RN']
# Distância total percorrida: 2759
#
# O caminho mais curto de PA para RN com o menor custo é:
# Caminho: ['PA', 'MA', 'PI', 'CE', 'PB', 'RN']
# Custo total percorrido: 13876.11
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para TO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para TO com a menor distância é:
# Caminho: ['PA', 'TO']
# Distância total percorrida: 1283
#
# O caminho mais curto de PA para TO com o menor custo é:
# Caminho: ['PA', 'TO']
# Custo total percorrido: 6889.71
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para RS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para RS com a menor distância é:
# Caminho: ['PA', 'DF', 'MG', 'SP', 'PR', 'SC', 'RS']
# Distância total percorrida: 3202
#
# O caminho mais curto de PA para RS com o menor custo é:
# Caminho: ['PA', 'DF', 'MG', 'SP', 'PR', 'SC', 'RS']
# Custo total percorrido: 15891.740000000002
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para RO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para RO com a menor distância é:
# Caminho: ['PA', 'DF', 'MT', 'RO']
# Distância total percorrida: 3305
#
# O caminho mais curto de PA para RO com o menor custo é:
# Caminho: ['PA', 'DF', 'MT', 'RO']
# Custo total percorrido: 16726.71
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para PE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para PE com a menor distância é:
# Caminho: ['PA', 'MA', 'PI', 'CE', 'PE']
# Distância total percorrida: 2686
#
# O caminho mais curto de PA para PE com o menor custo é:
# Caminho: ['PA', 'MA', 'PI', 'CE', 'PE']
# Custo total percorrido: 13561.84
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para AC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para AC com a menor distância é:
# Caminho: ['PA', 'DF', 'MT', 'RO', 'AC']
# Distância total percorrida: 3849
#
# O caminho mais curto de PA para AC com o menor custo é:
# Caminho: ['PA', 'DF', 'MT', 'RO', 'AC']
# Custo total percorrido: 19637.11
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para RJ...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para RJ com a menor distância é:
# Caminho: ['PA', 'DF', 'MG', 'RJ']
# Distância total percorrida: 1866
#
# O caminho mais curto de PA para RJ com o menor custo é:
# Caminho: ['PA', 'DF', 'MG', 'RJ']
# Custo total percorrido: 9353.42
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para BA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para BA com a menor distância é:
# Caminho: ['PA', 'DF', 'BA']
# Distância total percorrida: 2162
#
# O caminho mais curto de PA para BA com o menor custo é:
# Caminho: ['PA', 'DF', 'BA']
# Custo total percorrido: 10771.26
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para MA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para MA com a menor distância é:
# Caminho: ['PA', 'MA']
# Distância total percorrida: 806
#
# O caminho mais curto de PA para MA com o menor custo é:
# Caminho: ['PA', 'MA']
# Custo total percorrido: 4328.22
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para SP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para SP com a menor distância é:
# Caminho: ['PA', 'DF', 'MG', 'SP']
# Distância total percorrida: 2018
#
# O caminho mais curto de PA para SP com o menor custo é:
# Caminho: ['PA', 'DF', 'MG', 'SP']
# Custo total percorrido: 10081.5
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para PI...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para PI com a menor distância é:
# Caminho: ['PA', 'MA', 'PI']
# Distância total percorrida: 1252
#
# O caminho mais curto de PA para PI com o menor custo é:
# Caminho: ['PA', 'MA', 'PI']
# Custo total percorrido: 6442.26
#
# -----------------------------------------------------------
#
# Calculando caminho de PA para ES...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PA para ES com a menor distância é:
# Caminho: ['PA', 'DF', 'MG', 'ES']
# Distância total percorrida: 1956
#
# O caminho mais curto de PA para ES com o menor custo é:
# Caminho: ['PA', 'DF', 'MG', 'ES']
# Custo total percorrido: 9784.52
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para SE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para SE com a menor distância é:
# Caminho: ['MG', 'BA', 'SE']
# Distância total percorrida: 1728
#
# O caminho mais curto de MG para SE com o menor custo é:
# Caminho: ['MG', 'BA', 'SE']
# Custo total percorrido: 8394.6
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para PA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para PA com a menor distância é:
# Caminho: ['MG', 'GO', 'TO', 'PA']
# Distância total percorrida: 3063
#
# O caminho mais curto de MG para PA com o menor custo é:
# Caminho: ['MG', 'GO', 'TO', 'PA']
# Custo total percorrido: 14885.789999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para RR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para RR com a menor distância é:
# Caminho: ['MG', 'GO', 'MT', 'AM', 'RR']
# Distância total percorrida: 4982
#
# O caminho mais curto de MG para RR com o menor custo é:
# Caminho: ['MG', 'GO', 'MT', 'AM', 'RR']
# Custo total percorrido: 24941.379999999997
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para DF...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para DF com a menor distância é:
# Caminho: ['MG', 'GO', 'DF']
# Distância total percorrida: 1115
#
# O caminho mais curto de MG para DF com o menor custo é:
# Caminho: ['MG', 'GO', 'DF']
# Custo total percorrido: 5342.94
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para MS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para MS com a menor distância é:
# Caminho: ['MG', 'MS']
# Distância total percorrida: 1453
#
# O caminho mais curto de MG para MS com o menor custo é:
# Caminho: ['MG', 'MS']
# Custo total percorrido: 6959.87
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para MT...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para MT com a menor distância é:
# Caminho: ['MG', 'GO', 'MT']
# Distância total percorrida: 1840
#
# O caminho mais curto de MG para MT com o menor custo é:
# Caminho: ['MG', 'GO', 'MT']
# Custo total percorrido: 8822.939999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para PR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para PR com a menor distância é:
# Caminho: ['MG', 'SP', 'PR']
# Distância total percorrida: 994
#
# O caminho mais curto de MG para PR com o menor custo é:
# Caminho: ['MG', 'SP', 'PR']
# Custo total percorrido: 4810.22
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para SC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para SC com a menor distância é:
# Caminho: ['MG', 'SP', 'PR', 'SC']
# Distância total percorrida: 1294
#
# O caminho mais curto de MG para SC com o menor custo é:
# Caminho: ['MG', 'SP', 'PR', 'SC']
# Custo total percorrido: 6256.22
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para CE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para CE com a menor distância é:
# Caminho: ['MG', 'BA', 'PE', 'CE']
# Distância total percorrida: 3011
#
# O caminho mais curto de MG para CE com o menor custo é:
# Caminho: ['MG', 'BA', 'PE', 'CE']
# Custo total percorrido: 14971.560000000001
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para GO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para GO com a menor distância é:
# Caminho: ['MG', 'GO']
# Distância total percorrida: 906
#
# O caminho mais curto de MG para GO com o menor custo é:
# Caminho: ['MG', 'GO']
# Custo total percorrido: 4339.74
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para PB...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para PB com a menor distância é:
# Caminho: ['MG', 'BA', 'PE', 'PB']
# Distância total percorrida: 2331
#
# O caminho mais curto de MG para PB com o menor custo é:
# Caminho: ['MG', 'BA', 'PE', 'PB']
# Custo total percorrido: 11483.160000000002
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para AP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para AP com a menor distância é:
# Caminho: None
# Distância total percorrida: inf
#
# O caminho mais curto de MG para AP com o menor custo é:
# Caminho: None
# Custo total percorrido: inf
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para AL...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para AL com a menor distância é:
# Caminho: ['MG', 'BA', 'AL']
# Distância total percorrida: 2004
#
# O caminho mais curto de MG para AL com o menor custo é:
# Caminho: ['MG', 'BA', 'AL']
# Custo total percorrido: 9807.720000000001
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para AM...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para AM com a menor distância é:
# Caminho: ['MG', 'GO', 'MT', 'AM']
# Distância total percorrida: 4197
#
# O caminho mais curto de MG para AM com o menor custo é:
# Caminho: ['MG', 'GO', 'MT', 'AM']
# Custo total percorrido: 20890.78
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para RN...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para RN com a menor distância é:
# Caminho: ['MG', 'BA', 'PE', 'PB', 'RN']
# Distância total percorrida: 2516
#
# O caminho mais curto de MG para RN com o menor custo é:
# Caminho: ['MG', 'BA', 'PE', 'PB', 'RN']
# Custo total percorrido: 12361.910000000002
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para TO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para TO com a menor distância é:
# Caminho: ['MG', 'GO', 'TO']
# Distância total percorrida: 1780
#
# O caminho mais curto de MG para TO com o menor custo é:
# Caminho: ['MG', 'GO', 'TO']
# Custo total percorrido: 8534.939999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para RS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para RS com a menor distância é:
# Caminho: ['MG', 'SP', 'PR', 'SC', 'RS']
# Distância total percorrida: 1770
#
# O caminho mais curto de MG para RS com o menor custo é:
# Caminho: ['MG', 'SP', 'PR', 'SC', 'RS']
# Custo total percorrido: 8617.18
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para RO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para RO com a menor distância é:
# Caminho: ['MG', 'GO', 'MT', 'RO']
# Distância total percorrida: 3296
#
# O caminho mais curto de MG para RO com o menor custo é:
# Caminho: ['MG', 'GO', 'MT', 'RO']
# Custo total percorrido: 16277.66
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para PE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para PE com a menor distância é:
# Caminho: ['MG', 'BA', 'PE']
# Distância total percorrida: 2211
#
# O caminho mais curto de MG para PE com o menor custo é:
# Caminho: ['MG', 'BA', 'PE']
# Custo total percorrido: 10867.560000000001
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para AC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para AC com a menor distância é:
# Caminho: ['MG', 'GO', 'MT', 'RO', 'AC']
# Distância total percorrida: 3840
#
# O caminho mais curto de MG para AC com o menor custo é:
# Caminho: ['MG', 'GO', 'MT', 'RO', 'AC']
# Custo total percorrido: 19188.059999999998
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para RJ...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para RJ com a menor distância é:
# Caminho: ['MG', 'RJ']
# Distância total percorrida: 434
#
# O caminho mais curto de MG para RJ com o menor custo é:
# Caminho: ['MG', 'RJ']
# Custo total percorrido: 2078.86
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para BA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para BA com a menor distância é:
# Caminho: ['MG', 'BA']
# Distância total percorrida: 1372
#
# O caminho mais curto de MG para BA com o menor custo é:
# Caminho: ['MG', 'BA']
# Custo total percorrido: 6571.88
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para MA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para MA com a menor distância é:
# Caminho: ['MG', 'BA', 'PI', 'MA']
# Distância total percorrida: 2981
#
# O caminho mais curto de MG para MA com o menor custo é:
# Caminho: ['MG', 'BA', 'PI', 'MA']
# Custo total percorrido: 14698.460000000001
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para SP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para SP com a menor distância é:
# Caminho: ['MG', 'SP']
# Distância total percorrida: 586
#
# O caminho mais curto de MG para SP com o menor custo é:
# Caminho: ['MG', 'SP']
# Custo total percorrido: 2806.94
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para PI...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para PI com a menor distância é:
# Caminho: ['MG', 'BA', 'PI']
# Distância total percorrida: 2535
#
# O caminho mais curto de MG para PI com o menor custo é:
# Caminho: ['MG', 'BA', 'PI']
# Custo total percorrido: 12526.44
#
# -----------------------------------------------------------
#
# Calculando caminho de MG para ES...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de MG para ES com a menor distância é:
# Caminho: ['MG', 'ES']
# Distância total percorrida: 524
#
# O caminho mais curto de MG para ES com o menor custo é:
# Caminho: ['MG', 'ES']
# Custo total percorrido: 2509.96
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para SE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para SE com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'SE']
# Distância total percorrida: 6075
#
# O caminho mais curto de RR para SE com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'SE']
# Custo total percorrido: 30868.770000000004
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para PA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para PA com a menor distância é:
# Caminho: ['RR', 'AM', 'PA']
# Distância total percorrida: 6083
#
# O caminho mais curto de RR para PA com o menor custo é:
# Caminho: ['RR', 'AM', 'PA']
# Custo total percorrido: 31553.13
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para MG...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para MG com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'MG']
# Distância total percorrida: 4982
#
# O caminho mais curto de RR para MG com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'MG']
# Custo total percorrido: 25508.45
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para DF...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para DF com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'DF']
# Distância total percorrida: 4275
#
# O caminho mais curto de RR para DF com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'DF']
# Custo total percorrido: 22178.53
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para MS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para MS com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'MS']
# Distância total percorrida: 3836
#
# O caminho mais curto de RR para MS com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'MS']
# Custo total percorrido: 19930.85
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para MT...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para MT com a menor distância é:
# Caminho: ['RR', 'AM', 'MT']
# Distância total percorrida: 3142
#
# O caminho mais curto de RR para MT com o menor custo é:
# Caminho: ['RR', 'AM', 'MT']
# Custo total percorrido: 16377.57
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para PR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para PR com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'PR']
# Distância total percorrida: 4827
#
# O caminho mais curto de RR para PR com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'PR']
# Custo total percorrido: 24925.489999999998
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para SC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para SC com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'PR', 'SC']
# Distância total percorrida: 5127
#
# O caminho mais curto de RR para SC com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'PR', 'SC']
# Custo total percorrido: 26371.489999999998
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para CE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para CE com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'TO', 'PI', 'CE']
# Distância total percorrida: 6961
#
# O caminho mais curto de RR para CE com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'TO', 'PI', 'CE']
# Custo total percorrido: 35534.18
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para GO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para GO com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO']
# Distância total percorrida: 4076
#
# O caminho mais curto de RR para GO com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO']
# Custo total percorrido: 21159.65
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para PB...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para PB com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'PE', 'PB']
# Distância total percorrida: 6678
#
# O caminho mais curto de RR para PB com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'PE', 'PB']
# Custo total percorrido: 33957.33
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para AP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para AP com a menor distância é:
# Caminho: None
# Distância total percorrida: inf
#
# O caminho mais curto de RR para AP com o menor custo é:
# Caminho: None
# Custo total percorrido: inf
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para AL...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para AL com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'AL']
# Distância total percorrida: 6351
#
# O caminho mais curto de RR para AL com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'AL']
# Custo total percorrido: 32281.890000000003
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para AM...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para AM com a menor distância é:
# Caminho: ['RR', 'AM']
# Distância total percorrida: 785
#
# O caminho mais curto de RR para AM com o menor custo é:
# Caminho: ['RR', 'AM']
# Custo total percorrido: 4215.45
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para RN...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para RN com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'PE', 'PB', 'RN']
# Distância total percorrida: 6863
#
# O caminho mais curto de RR para RN com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'PE', 'PB', 'RN']
# Custo total percorrido: 34836.08
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para TO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para TO com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'TO']
# Distância total percorrida: 4926
#
# O caminho mais curto de RR para TO com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'TO']
# Custo total percorrido: 25511.65
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para RS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para RS com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'PR', 'SC', 'RS']
# Distância total percorrida: 5603
#
# O caminho mais curto de RR para RS com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'PR', 'SC', 'RS']
# Custo total percorrido: 28732.449999999997
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para RO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para RO com a menor distância é:
# Caminho: ['RR', 'AM', 'RO']
# Distância total percorrida: 1686
#
# O caminho mais curto de RR para RO com o menor custo é:
# Caminho: ['RR', 'AM', 'RO']
# Custo total percorrido: 8864.61
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para PE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para PE com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'PE']
# Distância total percorrida: 6558
#
# O caminho mais curto de RR para PE com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA', 'PE']
# Custo total percorrido: 33341.73
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para AC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para AC com a menor distância é:
# Caminho: ['RR', 'AM', 'AC']
# Distância total percorrida: 2230
#
# O caminho mais curto de RR para AC com o menor custo é:
# Caminho: ['RR', 'AM', 'AC']
# Custo total percorrido: 11671.65
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para RJ...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para RJ com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'SP', 'RJ']
# Distância total percorrida: 5279
#
# O caminho mais curto de RR para RJ com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'SP', 'RJ']
# Custo total percorrido: 27147.8
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para BA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para BA com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA']
# Distância total percorrida: 5719
#
# O caminho mais curto de RR para BA com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'BA']
# Custo total percorrido: 29046.050000000003
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para MA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para MA com a menor distância é:
# Caminho: ['RR', 'AM', 'MA']
# Distância total percorrida: 6120
#
# O caminho mais curto de RR para MA com o menor custo é:
# Caminho: ['RR', 'AM', 'MA']
# Custo total percorrido: 31744.050000000003
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para SP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para SP com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'SP']
# Distância total percorrida: 4850
#
# O caminho mais curto de RR para SP com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'MS', 'SP']
# Custo total percorrido: 25041.41
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para PI...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para PI com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'TO', 'PI']
# Distância total percorrida: 6327
#
# O caminho mais curto de RR para PI com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'TO', 'PI']
# Custo total percorrido: 32446.600000000002
#
# -----------------------------------------------------------
#
# Calculando caminho de RR para ES...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de RR para ES com a menor distância é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'MG', 'ES']
# Distância total percorrida: 5506
#
# O caminho mais curto de RR para ES com o menor custo é:
# Caminho: ['RR', 'AM', 'MT', 'GO', 'MG', 'ES']
# Custo total percorrido: 28018.41
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para SE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para SE com a menor distância é:
# Caminho: ['DF', 'BA', 'SE']
# Distância total percorrida: 1802
#
# O caminho mais curto de DF para SE com o menor custo é:
# Caminho: ['DF', 'BA', 'SE']
# Custo total percorrido: 8749.06
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para PA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para PA com a menor distância é:
# Caminho: ['DF', 'TO', 'PA']
# Distância total percorrida: 2256
#
# O caminho mais curto de DF para PA com o menor custo é:
# Caminho: ['DF', 'TO', 'PA']
# Custo total percorrido: 11011.52
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para MG...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para MG com a menor distância é:
# Caminho: ['DF', 'MG']
# Distância total percorrida: 716
#
# O caminho mais curto de DF para MG com o menor custo é:
# Caminho: ['DF', 'MG']
# Custo total percorrido: 3429.64
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para RR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para RR com a menor distância é:
# Caminho: ['DF', 'MT', 'AM', 'RR']
# Distância total percorrida: 4275
#
# O caminho mais curto de DF para RR com o menor custo é:
# Caminho: ['DF', 'MT', 'AM', 'RR']
# Custo total percorrido: 21545.51
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para MS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para MS com a menor distância é:
# Caminho: ['DF', 'MS']
# Distância total percorrida: 1134
#
# O caminho mais curto de DF para MS com o menor custo é:
# Caminho: ['DF', 'MS']
# Custo total percorrido: 5431.86
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para MT...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para MT com a menor distância é:
# Caminho: ['DF', 'MT']
# Distância total percorrida: 1133
#
# O caminho mais curto de DF para MT com o menor custo é:
# Caminho: ['DF', 'MT']
# Custo total percorrido: 5427.07
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para PR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para PR com a menor distância é:
# Caminho: ['DF', 'MG', 'SP', 'PR']
# Distância total percorrida: 1710
#
# O caminho mais curto de DF para PR com o menor custo é:
# Caminho: ['DF', 'MG', 'SP', 'PR']
# Custo total percorrido: 8239.86
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para SC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para SC com a menor distância é:
# Caminho: ['DF', 'MG', 'SP', 'PR', 'SC']
# Distância total percorrida: 2010
#
# O caminho mais curto de DF para SC com o menor custo é:
# Caminho: ['DF', 'MG', 'SP', 'PR', 'SC']
# Custo total percorrido: 9685.86
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para CE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para CE com a menor distância é:
# Caminho: ['DF', 'TO', 'PI', 'CE']
# Distância total percorrida: 3008
#
# O caminho mais curto de DF para CE com o menor custo é:
# Caminho: ['DF', 'TO', 'PI', 'CE']
# Custo total percorrido: 14683.199999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para GO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para GO com a menor distância é:
# Caminho: ['DF', 'GO']
# Distância total percorrida: 209
#
# O caminho mais curto de DF para GO com o menor custo é:
# Caminho: ['DF', 'GO']
# Custo total percorrido: 1001.11
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para PB...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para PB com a menor distância é:
# Caminho: ['DF', 'BA', 'PE', 'PB']
# Distância total percorrida: 2405
#
# O caminho mais curto de DF para PB com o menor custo é:
# Caminho: ['DF', 'BA', 'PE', 'PB']
# Custo total percorrido: 11837.62
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para AP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para AP com a menor distância é:
# Caminho: None
# Distância total percorrida: inf
#
# O caminho mais curto de DF para AP com o menor custo é:
# Caminho: None
# Custo total percorrido: inf
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para AL...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para AL com a menor distância é:
# Caminho: ['DF', 'BA', 'AL']
# Distância total percorrida: 2078
#
# O caminho mais curto de DF para AL com o menor custo é:
# Caminho: ['DF', 'BA', 'AL']
# Custo total percorrido: 10162.18
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para AM...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para AM com a menor distância é:
# Caminho: ['DF', 'MT', 'AM']
# Distância total percorrida: 3490
#
# O caminho mais curto de DF para AM com o menor custo é:
# Caminho: ['DF', 'MT', 'AM']
# Custo total percorrido: 17494.91
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para RN...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para RN com a menor distância é:
# Caminho: ['DF', 'BA', 'PE', 'PB', 'RN']
# Distância total percorrida: 2590
#
# O caminho mais curto de DF para RN com o menor custo é:
# Caminho: ['DF', 'BA', 'PE', 'PB', 'RN']
# Custo total percorrido: 12716.37
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para TO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para TO com a menor distância é:
# Caminho: ['DF', 'TO']
# Distância total percorrida: 973
#
# O caminho mais curto de DF para TO com o menor custo é:
# Caminho: ['DF', 'TO']
# Custo total percorrido: 4660.67
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para RS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para RS com a menor distância é:
# Caminho: ['DF', 'MG', 'SP', 'PR', 'SC', 'RS']
# Distância total percorrida: 2486
#
# O caminho mais curto de DF para RS com o menor custo é:
# Caminho: ['DF', 'MG', 'SP', 'PR', 'SC', 'RS']
# Custo total percorrido: 12046.82
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para RO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para RO com a menor distância é:
# Caminho: ['DF', 'MT', 'RO']
# Distância total percorrida: 2589
#
# O caminho mais curto de DF para RO com o menor custo é:
# Caminho: ['DF', 'MT', 'RO']
# Custo total percorrido: 12881.79
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para PE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de DF para PE com a menor distância é:
# Caminho: ['DF', 'BA', 'PE']
# Distância total percorrida: 2285
#
# O caminho mais curto de DF para PE com o menor custo é:
# Caminho: ['DF', 'BA', 'PE']
# Custo total percorrido: 11222.02
#
# -----------------------------------------------------------
#
# Calculando caminho de DF para AC...
#
#
#
# ...
#
# Calculando caminho de PI para PB...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para PB com a menor distância é:
# Caminho: ['PI', 'CE', 'PB']
# Distância total percorrida: 1322
#
# O caminho mais curto de PI para PB com o menor custo é:
# Caminho: ['PI', 'CE', 'PB']
# Custo total percorrido: 6555.1
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para AP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para AP com a menor distância é:
# Caminho: None
# Distância total percorrida: inf
#
# O caminho mais curto de PI para AP com o menor custo é:
# Caminho: None
# Custo total percorrido: inf
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para AL...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para AL com a menor distância é:
# Caminho: ['PI', 'BA', 'AL']
# Distância total percorrida: 1795
#
# O caminho mais curto de PI para AL com o menor custo é:
# Caminho: ['PI', 'BA', 'AL']
# Custo total percorrido: 8899.650000000001
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para AM...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para AM com a menor distância é:
# Caminho: ['PI', 'MA', 'PA', 'DF', 'MT', 'AM']
# Distância total percorrida: 5458
#
# O caminho mais curto de PI para AM com o menor custo é:
# Caminho: ['PI', 'MA', 'PA', 'DF', 'MT', 'AM']
# Custo total percorrido: 27332.29
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para RN...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para RN com a menor distância é:
# Caminho: ['PI', 'CE', 'PB', 'RN']
# Distância total percorrida: 1507
#
# O caminho mais curto de PI para RN com o menor custo é:
# Caminho: ['PI', 'CE', 'PB', 'RN']
# Custo total percorrido: 7433.85
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para TO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para TO com a menor distância é:
# Caminho: ['PI', 'MA', 'TO']
# Distância total percorrida: 1832
#
# O caminho mais curto de PI para TO com o menor custo é:
# Caminho: ['PI', 'MA', 'TO']
# Custo total percorrido: 8741.66
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para RS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para RS com a menor distância é:
# Caminho: ['PI', 'BA', 'MG', 'SP', 'PR', 'SC', 'RS']
# Distância total percorrida: 4305
#
# O caminho mais curto de PI para RS com o menor custo é:
# Caminho: ['PI', 'BA', 'MG', 'SP', 'PR', 'SC', 'RS']
# Custo total percorrido: 21305.63
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para RO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para RO com a menor distância é:
# Caminho: ['PI', 'MA', 'PA', 'DF', 'MT', 'RO']
# Distância total percorrida: 4557
#
# O caminho mais curto de PI para RO com o menor custo é:
# Caminho: ['PI', 'MA', 'PA', 'DF', 'MT', 'RO']
# Custo total percorrido: 22719.170000000002
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para PE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para PE com a menor distância é:
# Caminho: ['PI', 'CE', 'PE']
# Distância total percorrida: 1434
#
# O caminho mais curto de PI para PE com o menor custo é:
# Caminho: ['PI', 'CE', 'PE']
# Custo total percorrido: 7119.58
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para AC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para AC com a menor distância é:
# Caminho: ['PI', 'MA', 'PA', 'DF', 'MT', 'RO', 'AC']
# Distância total percorrida: 5101
#
# O caminho mais curto de PI para AC com o menor custo é:
# Caminho: ['PI', 'MA', 'PA', 'DF', 'MT', 'RO', 'AC']
# Custo total percorrido: 25629.57
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para RJ...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para RJ com a menor distância é:
# Caminho: ['PI', 'BA', 'ES', 'RJ']
# Distância total percorrida: 2886
#
# O caminho mais curto de PI para RJ com o menor custo é:
# Caminho: ['PI', 'BA', 'ES', 'RJ']
# Custo total percorrido: 14365.74
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para BA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para BA com a menor distância é:
# Caminho: ['PI', 'BA']
# Distância total percorrida: 1163
#
# O caminho mais curto de PI para BA com o menor custo é:
# Caminho: ['PI', 'BA']
# Custo total percorrido: 5663.81
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para MA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para MA com a menor distância é:
# Caminho: ['PI', 'MA']
# Distância total percorrida: 446
#
# O caminho mais curto de PI para MA com o menor custo é:
# Caminho: ['PI', 'MA']
# Custo total percorrido: 2172.02
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para SP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para SP com a menor distância é:
# Caminho: ['PI', 'BA', 'MG', 'SP']
# Distância total percorrida: 3121
#
# O caminho mais curto de PI para SP com o menor custo é:
# Caminho: ['PI', 'BA', 'MG', 'SP']
# Custo total percorrido: 15495.390000000001
#
# -----------------------------------------------------------
#
# Calculando caminho de PI para ES...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de PI para ES com a menor distância é:
# Caminho: ['PI', 'BA', 'ES']
# Distância total percorrida: 2365
#
# O caminho mais curto de PI para ES com o menor custo é:
# Caminho: ['PI', 'BA', 'ES']
# Custo total percorrido: 11818.05
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para SE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para SE com a menor distância é:
# Caminho: ['ES', 'BA', 'SE']
# Distância total percorrida: 1558
#
# O caminho mais curto de ES para SE com o menor custo é:
# Caminho: ['ES', 'BA', 'SE']
# Custo total percorrido: 7700.5
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para PA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para PA com a menor distância é:
# Caminho: ['ES', 'MG', 'GO', 'TO', 'PA']
# Distância total percorrida: 3587
#
# O caminho mais curto de ES para PA com o menor custo é:
# Caminho: ['ES', 'MG', 'GO', 'TO', 'PA']
# Custo total percorrido: 17448.15
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para MG...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para MG com a menor distância é:
# Caminho: ['ES', 'MG']
# Distância total percorrida: 524
#
# O caminho mais curto de ES para MG com o menor custo é:
# Caminho: ['ES', 'MG']
# Custo total percorrido: 2562.3599999999997
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para RR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para RR com a menor distância é:
# Caminho: ['ES', 'MG', 'GO', 'MT', 'AM', 'RR']
# Distância total percorrida: 5506
#
# O caminho mais curto de ES para RR com o menor custo é:
# Caminho: ['ES', 'MG', 'GO', 'MT', 'AM', 'RR']
# Custo total percorrido: 27503.739999999998
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para DF...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para DF com a menor distância é:
# Caminho: ['ES', 'MG', 'GO', 'DF']
# Distância total percorrida: 1639
#
# O caminho mais curto de ES para DF com o menor custo é:
# Caminho: ['ES', 'MG', 'GO', 'DF']
# Custo total percorrido: 7905.299999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para MS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para MS com a menor distância é:
# Caminho: ['ES', 'RJ', 'SP', 'MS']
# Distância total percorrida: 1964
#
# O caminho mais curto de ES para MS com o menor custo é:
# Caminho: ['ES', 'RJ', 'SP', 'MS']
# Custo total percorrido: 9697.17
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para MT...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para MT com a menor distância é:
# Caminho: ['ES', 'MG', 'GO', 'MT']
# Distância total percorrida: 2364
#
# O caminho mais curto de ES para MT com o menor custo é:
# Caminho: ['ES', 'MG', 'GO', 'MT']
# Custo total percorrido: 11385.3
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para PR...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para PR com a menor distância é:
# Caminho: ['ES', 'RJ', 'SP', 'PR']
# Distância total percorrida: 1358
#
# O caminho mais curto de ES para PR com o menor custo é:
# Caminho: ['ES', 'RJ', 'SP', 'PR']
# Custo total percorrido: 6721.71
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para SC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para SC com a menor distância é:
# Caminho: ['ES', 'RJ', 'SP', 'PR', 'SC']
# Distância total percorrida: 1658
#
# O caminho mais curto de ES para SC com o menor custo é:
# Caminho: ['ES', 'RJ', 'SP', 'PR', 'SC']
# Custo total percorrido: 8167.71
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para CE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para CE com a menor distância é:
# Caminho: ['ES', 'BA', 'PE', 'CE']
# Distância total percorrida: 2841
#
# O caminho mais curto de ES para CE com o menor custo é:
# Caminho: ['ES', 'BA', 'PE', 'CE']
# Custo total percorrido: 14277.46
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para GO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para GO com a menor distância é:
# Caminho: ['ES', 'MG', 'GO']
# Distância total percorrida: 1430
#
# O caminho mais curto de ES para GO com o menor custo é:
# Caminho: ['ES', 'MG', 'GO']
# Custo total percorrido: 6902.099999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para PB...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para PB com a menor distância é:
# Caminho: ['ES', 'BA', 'PE', 'PB']
# Distância total percorrida: 2161
#
# O caminho mais curto de ES para PB com o menor custo é:
# Caminho: ['ES', 'BA', 'PE', 'PB']
# Custo total percorrido: 10789.06
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para AP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para AP com a menor distância é:
# Caminho: None
# Distância total percorrida: inf
#
# O caminho mais curto de ES para AP com o menor custo é:
# Caminho: None
# Custo total percorrido: inf
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para AL...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para AL com a menor distância é:
# Caminho: ['ES', 'BA', 'AL']
# Distância total percorrida: 1834
#
# O caminho mais curto de ES para AL com o menor custo é:
# Caminho: ['ES', 'BA', 'AL']
# Custo total percorrido: 9113.619999999999
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para AM...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para AM com a menor distância é:
# Caminho: ['ES', 'MG', 'GO', 'MT', 'AM']
# Distância total percorrida: 4721
#
# O caminho mais curto de ES para AM com o menor custo é:
# Caminho: ['ES', 'MG', 'GO', 'MT', 'AM']
# Custo total percorrido: 23453.14
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para RN...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para RN com a menor distância é:
# Caminho: ['ES', 'BA', 'PE', 'PB', 'RN']
# Distância total percorrida: 2346
#
# O caminho mais curto de ES para RN com o menor custo é:
# Caminho: ['ES', 'BA', 'PE', 'PB', 'RN']
# Custo total percorrido: 11667.81
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para TO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para TO com a menor distância é:
# Caminho: ['ES', 'MG', 'GO', 'TO']
# Distância total percorrida: 2304
#
# O caminho mais curto de ES para TO com o menor custo é:
# Caminho: ['ES', 'MG', 'GO', 'TO']
# Custo total percorrido: 11097.3
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para RS...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para RS com a menor distância é:
# Caminho: ['ES', 'RJ', 'SP', 'PR', 'SC', 'RS']
# Distância total percorrida: 2134
#
# O caminho mais curto de ES para RS com o menor custo é:
# Caminho: ['ES', 'RJ', 'SP', 'PR', 'SC', 'RS']
# Custo total percorrido: 10528.67
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para RO...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para RO com a menor distância é:
# Caminho: ['ES', 'MG', 'GO', 'MT', 'RO']
# Distância total percorrida: 3820
#
# O caminho mais curto de ES para RO com o menor custo é:
# Caminho: ['ES', 'MG', 'GO', 'MT', 'RO']
# Custo total percorrido: 18840.02
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para PE...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para PE com a menor distância é:
# Caminho: ['ES', 'BA', 'PE']
# Distância total percorrida: 2041
#
# O caminho mais curto de ES para PE com o menor custo é:
# Caminho: ['ES', 'BA', 'PE']
# Custo total percorrido: 10173.46
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para AC...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para AC com a menor distância é:
# Caminho: ['ES', 'MG', 'GO', 'MT', 'RO', 'AC']
# Distância total percorrida: 4364
#
# O caminho mais curto de ES para AC com o menor custo é:
# Caminho: ['ES', 'MG', 'GO', 'MT', 'RO', 'AC']
# Custo total percorrido: 21750.42
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para RJ...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para RJ com a menor distância é:
# Caminho: ['ES', 'RJ']
# Distância total percorrida: 521
#
# O caminho mais curto de ES para RJ com o menor custo é:
# Caminho: ['ES', 'RJ']
# Custo total percorrido: 2547.69
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para BA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para BA com a menor distância é:
# Caminho: ['ES', 'BA']
# Distância total percorrida: 1202
#
# O caminho mais curto de ES para BA com o menor custo é:
# Caminho: ['ES', 'BA']
# Custo total percorrido: 5877.78
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para MA...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para MA com a menor distância é:
# Caminho: ['ES', 'BA', 'PI', 'MA']
# Distância total percorrida: 2811
#
# O caminho mais curto de ES para MA com o menor custo é:
# Caminho: ['ES', 'BA', 'PI', 'MA']
# Custo total percorrido: 14004.36
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para SP...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para SP com a menor distância é:
# Caminho: ['ES', 'RJ', 'SP']
# Distância total percorrida: 950
#
# O caminho mais curto de ES para SP com o menor custo é:
# Caminho: ['ES', 'RJ', 'SP']
# Custo total percorrido: 4718.43
#
# -----------------------------------------------------------
#
# Calculando caminho de ES para PI...
#
#
#
# ############## SOLUÇÃO ##############
# O caminho mais curto de ES para PI com a menor distância é:
# Caminho: ['ES', 'BA', 'PI']
# Distância total percorrida: 2365
#
# O caminho mais curto de ES para PI com o menor custo é:
# Caminho: ['ES', 'BA', 'PI']
# Custo total percorrido: 11832.34
#
# -----------------------------------------------------------
